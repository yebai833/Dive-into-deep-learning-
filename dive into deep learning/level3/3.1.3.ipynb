# %% [markdown]
# 正态分布与平方损失:
#
# 先定义一个Python函数，用于计算正态分布：

# %%
# %matplotlib inline
import math
import time
import numpy as np
import torch
from d2l import torch as d2l

def normal(x, mu, sigma):
    p = 1 / math.sqrt(2 * math.pi*sigma**2)
    return p*np.exp(-0.5/sigma**2*(x-mu)**2)

# %% [markdown]
# 可视化正态分布：

# %%
#使用numpy可视化正态分布
x=np.arange(-7,7,0.01)

#均值和标准差对
params=[(0,1),(0,2), (3,1)]
d2l.plot(x,[normal(x, mu, sigma) for mu, sigma in params], 
xlabel='x', ylabel='p(x)', legend=[f'μ={mu}, σ={sigma}' for mu, sigma in params])
